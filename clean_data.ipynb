# %%
import pandas as pd

# %%
df = pd.read_csv('data/last_comix_characters_info.csv')
df
# Out:
#                   Name Alignment  Gender EyeColor            Race HairColor  \
# 0    Alfred Pennyworth      good    Male     blue           Human     Black
# 1              Ant-Man      good    Male     blue           Human     Blond
# 2           Anti-Venom         -    Male     blue        Symbiote     Blond
# 3              Aqualad      good    Male     blue       Atlantean     Black
# 4              Aquaman      good    Male     blue       Atlantean     Blond
# ..                 ...       ...     ...      ...             ...       ...
# 117          Wolverine      good    Male     blue          Mutant     Black
# 118       Wonder Woman      good  Female     blue          Amazon     Black
# 119               X-23      good  Female    green  Mutant / Clone     Black
# 120               Yoda      good    Male    brown  Yoda's species     White
# 121               Zoom       bad    Male      red               -     Brown
#
#          Publisher SkinColor  Height  Weight
# ...

# %%
# Dropping duplicates based on specified columns
df_dropped = df.drop_duplicates(subset=['Alignment', 'Gender', 'EyeColor', 'Race', 'HairColor', 'Publisher', 'SkinColor'])

# Displaying the first few rows of the modified dataframe
df_dropped
# Out:
#                 Name Alignment Gender EyeColor       Race HairColor  \
# 0  Alfred Pennyworth      good   Male     blue      Human     Black
# 1            Ant-Man      good   Male     blue      Human     Blond
# 2         Anti-Venom         -   Male     blue   Symbiote     Blond
# 3            Aqualad      good   Male     blue  Atlantean     Black
# 4            Aquaman      good   Male     blue  Atlantean     Blond
#
#        Publisher SkinColor  Height  Weight
# 0      DC Comics         -     178      72
# 1  Marvel Comics         -     211     122
# 2  Marvel Comics         -     229     358
# 3      DC Comics         -     178     106
# 4      DC Comics         -     185     146

# %%
df_dropped
# Out:
#                   Name Alignment  Gender EyeColor            Race HairColor  \
# 0    Alfred Pennyworth      good    Male     blue           Human     Black
# 1              Ant-Man      good    Male     blue           Human     Blond
# 2           Anti-Venom         -    Male     blue        Symbiote     Blond
# 3              Aqualad      good    Male     blue       Atlantean     Black
# 4              Aquaman      good    Male     blue       Atlantean     Blond
# ..                 ...       ...     ...      ...             ...       ...
# 115               Wasp      good  Female     blue           Human    Auburn
# 117          Wolverine      good    Male     blue          Mutant     Black
# 119               X-23      good  Female    green  Mutant / Clone     Black
# 120               Yoda      good    Male    brown  Yoda's species     White
# 121               Zoom       bad    Male      red               -     Brown
#
#          Publisher SkinColor  Height  Weight
# ...

# %%
df_dropped.to_csv('data/T_comix_characters_no_duplicates.csv', index=False)
